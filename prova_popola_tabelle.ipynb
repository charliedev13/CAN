# %%
import pandas as pd

regioni = pd.read_csv('Regioni.csv')
regioni
# Out:
#                   Regione Superficie Kmq  \
# 0                 Abruzzo      10.828,89
# 1              Basilicata      10.071,59
# 2                Calabria      15.212,65
# 3                Campania      13.667,85
# 4          Emilia-Romagna      22.501,82
# 5   Friuli Venezia Giulia       7.936,83
# 6                   Lazio      17.236,49
# 7                 Liguria       5.417,71
# 8               Lombardia      23.862,87
# 9                  Marche       9.344,54
# 10                 Molise       4.459,80
# 11               Piemonte      25.391,67
# 12                 Puglia      19.541,03
# 13               Sardegna      24.106,30
# 14                Sicilia      25.824,33
# 15                Toscana      22.985,01
# 16    Trentino-Alto Adige      13.605,97
# 17                 Umbria       8.463,97
# 18          Valle d'Aosta       3.258,61
# 19                 Veneto      18.351,49
#
#     densita_demografica_kmq\nabitanti/km² PIL per abitante (migliaia di €)
# ...
